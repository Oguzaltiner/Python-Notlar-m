# %% [markdown]
# <a href="https://colab.research.google.com/github/Oguzaltiner/Python-Notlar-m/blob/master/ELK_kurulum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ELK NEDİR? Elasticsearch, Kibana ve Logstash Kurulumu(Windows)**

# %% [markdown]
# Merhabalar,
# Bu yazıda ELK nedir ve Windows'a nasıl kurulur onu anlatacağım.

# %% [markdown]
# #Elastic Stack Nedir?

# %% [markdown]
# Açık kaynak kodlu log toplama, arama ve analiz bileşenlerinin tamamına verilen genel addır.

# %% [markdown]
# **ELK YAPISI**
# ![9.png](data:image/png;base64,...)

# %% [markdown]
# ##**ElasticSearch Nedir?**

# %% [markdown]
# Elasticsearch, Apache Lucene üzerinde geliştirilmiş açık kaynak kodlu RestFul, dağıtılmış arama ve analitik altyapısıdır.
# Elasticsearch, yayımladığı 2010 yılından itibaren en popüler arama altyapısı haline gelmiştir ve genellikle günlük analitiği, tam metin arama, güvenlik zekası, iş analitiği ve operasyonel zeka kullanım örnekleri için tercih edilmektedir.

# %% [markdown]
# ##**Elasticsearch Nasıl Çalışır?**

# %% [markdown]
# Logstash ve Amozon Kinesis Firehose gibi API veya ekleme araçlarını kullanarak Elasticsearch'e JSON belgesi biçiminde veri gönderebilirsiniz.

# %% [markdown]
# Elasticsearch özgün belgeyi otomatik olarak depolar ve küme dizinine aranabilir belge başvurusu ekler.Daha sonra Elasticsearch API'sini kullanarak belgeyi arayabilir ve alabilirsiniz.

# %% [markdown]
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# #**Kibana Nedir**

# %% [markdown]
# Kibana, genellikle Elastic Stack için grafik aracı olarak bilinir.
# Ayrıca bir Elastic Stack kümesini izlemek, yönetmek ve güvenlik sağlamak için kullanıcı arabirimi görevi görür.

# %% [markdown]
# **Kibana: İster kullanıcı ister yönetici olun, Kibana üç temel işlev sağlayarak verilerinizi işlem yapılabilir hale getirir.**

# %% [markdown]
# * Açık kaynaklı bir analiz ve görselleştirme platformu
# * Elastik Yığını yönetmek için bir kullanıcı arayüzü.
# * Elastik Stack için merkezi çözümler.

# %% [markdown]
# **Kibana Arayüzü**

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# #**Logstash Nedir?**

# %% [markdown]
# Log toplayan, ihtiyaca göre onları işleyen ve Elasticsearch'e bu logları indekslenmek üzere gönderen sistemdir.
#
# Tipik bir konfigürasyonu şöyledir;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Beats Nedir**

# %% [markdown]
# Beats ürün ailesinin üyelerini kabaca sistemlerden Logstash'a log gönderen ajanlar olarak düşünebiliriz.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Java Kurulumu**

# %% [markdown]
# ElasticSearch, Logstash ve Kibana'nın düzgün çalışması için Java 8-11-14 sürümlerinden birtanesinin yüklenmesi gereklidir.

# %% [markdown]
# JDK-14 İndirilmesi:https://www.oracle.com/java/technologies/javase/jdk14-archive-downloads.html

# %% [markdown]
# **JDK'nın Sistem Değişkeni oluşturulması**

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# **Path üzerinde yeni Ortam Değişkeni oluşturmalıyız**

# %% [markdown]
# * Jdk ortam değişkeni oluşturduk.
#
#
#
#
# * Java_Home ortam değişkeni oluşturduk.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**ElasticSearch Windows Kurulumu**

# %% [markdown]
# **ElasticSearch-7.9.2 İndirme Linki:** https://www.elastic.co/downloads/elasticsearch

# %% [markdown]
# **Elasticsearch için ortam değişkeni oluşturmalıyız**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# elasticsearch-7.9.2\bin Klasörü içerisinde elasticsearch.bat dosyasını yönetici olarak çalıştırmak ElasticSearch'ün çalışması için yeterlidir.
#
# Bir diğer yolu ise PowerShell'i açıp sırasıyla aşağıdaki işlemleri yapmaktır.
#
# * cd elasticsearch-7.9.2\bin
# * elasticsearch.bat

# %% [markdown]
# **ElasticSearch http://localhost:9200/ portunda çalışmaya başlamıştır**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Kibana Kurulumu**

# %% [markdown]
# **Not:** Elasticsearch'ü çalıştırmadan Kibana çalışmaz.

# %% [markdown]
# **Kibana-7.9.2 İndirme Linki:** https://www.elastic.co/downloads/kibana

# %% [markdown]
# **Kibana için ortam değişkeni oluşturmalıyız.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# kibana-7.9.2-windows-x86_64\bin klasörü içinde kibana.bat dosyasını yönetici olarak çalıştırmak için yeterlidir.
#
# PowerShell ile kurulumu:
# * cd kibana-7.9.2-windows-x86_64\bin
# * kibana.bat

# %% [markdown]
# **Kibana 5601 portunda ayağa kalkmıştır.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Logstash Kurulumu**

# %% [markdown]
# **Not:** Elasticsearch ve Kibana çalışır durumdayken Logstash çalıştırılır aksi durumda çalışmaz.

# %% [markdown]
# ** Logstash-5.0 indirme linki:**https://www.elastic.co/downloads/past-releases/logstash-5-0-0

# %% [markdown]
# **Logstash için ortam değişkeni oluşturmalıyız.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Logstash'i çalıştırmak için   configürasyon dosyayı oluşturmamız lazım.

# %% [markdown]
# logstash-5.0.0\bin klasörü içine logstash.conf adında bir dosya oluşturalım

# %% [markdown]
# **logstash.conf**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# logstash -f logstash.conf ile 9600 portunda Logstash'i çalıştırdık

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **İnput dosyasına girilen mesajlar outputs dosyasında gösterilecektir**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
